# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 27160, done.
# remote: Counting objects: 100% (1816/1816), done.
# remote: Compressing objects: 100% (962/962), done.
# remote: Total 27160 (delta 1210), reused 1337 (delta 850), pack-reused 25344
# Receiving objects: 100% (27160/27160), 15.86 MiB | 22.39 MiB/s, done.
# Resolving deltas: 100% (19164/19164), done.

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.4/778.4 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 48.3 MB/s eta 0:00:00

# %%
# %cd /content/drive/MyDrive/person-detection
# Out:
# /content/drive/MyDrive/person-detection

# %%
# !yolo train model=yolov8n.pt data=/content/drive/MyDrive/person-detection/person.yaml epochs=50 imgsz=640 batch=32
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
