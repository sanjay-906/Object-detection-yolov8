# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 27411, done.
# remote: Counting objects: 100% (2067/2067), done.
# remote: Compressing objects: 100% (1098/1098), done.
# remote: Total 27411 (delta 1391), reused 1503 (delta 965), pack-reused 25344
# Receiving objects: 100% (27411/27411), 15.95 MiB | 17.66 MiB/s, done.
# Resolving deltas: 100% (19345/19345), done.

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.7/778.7 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 63.3 MB/s eta 0:00:00

# %%
# %cd /content/drive/MyDrive/ppe-detection
# Out:
# /content/drive/MyDrive/ppe-detection

# %%
# !yolo train model=yolov8m.pt data=/content/drive/MyDrive/ppe-detection/ppe.yaml epochs=50 imgsz=640 batch=32
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 235MB/s]
# Ultralytics YOLOv8.2.23 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
